# %%
from pyspark import SparkConf, SparkContext

# I run spark on Spark-Yarn mode, therefore setMaster('yarn') 
conf = SparkConf().setMaster("yarn").setAppName("Lab 2")

# It is not permitted to create new SparkContext while the previous one is running
# Therefore, get the previous one if exists
sc = SparkContext.getOrCreate(conf=conf)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-03656c29c9b7> in <module>
# ----> 1 from pyspark import SparkConf, SparkContext
#       2
#       3 # I run spark on Spark-Yarn mode, therefore setMaster('yarn')
#       4 conf = SparkConf().setMaster("yarn").setAppName("Lab 2")
#       5
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyspark/__init__.py in <module>
#      49
#      50 from pyspark.conf import SparkConf
# ---> 51 from pyspark.context import SparkContext
#      52 from pyspark.rdd import RDD, RDDBarrier
#      53 from pyspark.files import SparkFiles
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyspark/context.py in <module>
#      29 from py4j.protocol import Py4JError
#      30
# ---> 31 from pyspark import accumulators
#      32 from pyspark.accumulators import Accumulator
#      33 from pyspark.broadcast import Broadcast, BroadcastPickleRegistry
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyspark/accumulators.py in <module>
#      95     import socketserver as SocketServer
#      96 import threading
# ---> 97 from pyspark.serializers import read_int, PickleSerializer
#      98
#      99
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyspark/serializers.py in <module>
#      69     xrange = range
#      70
# ---> 71 from pyspark import cloudpickle
#      72 from pyspark.util import _exception_message
#      73
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyspark/cloudpickle.py in <module>
#     143
#     144
# --> 145 _cell_set_template_code = _make_cell_set_template_code()
#     146
#     147
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyspark/cloudpickle.py in _make_cell_set_template_code()
#     124         )
#     125     else:
# --> 126         return types.CodeType(
#     127             co.co_argcount,
#     128             co.co_kwonlyargcount,
#
# TypeError: an integer is required (got type bytes)

# %%
# display my SparkContext information
sc
# Out:
# <SparkContext master=yarn appName=Lab 2>

# %%
# this function is implemented to remove special character. Only letter is kept
# "Hey!!!" --> "Hey" 

def deleteSpecialCharacter(string):
    result = ''
    for character in string:
        if (character <= 'z' and character >= 'a') or (character >= 'A' and character <= 'Z'):
            result += character
    return result

# %%
# this function is implemented to transform text to list of words
# "Hello World!! Love you." --> return ['hello', 'world', 'love', 'you']

def toWordList(line_of_words):
    line_of_words = line_of_words.lower()
    word_list = line_of_words.split(" ")
    for i in range(0, len(word_list)):
        word_list[i] = deleteSpecialCharacter(word_list[i])
    while '' in word_list:
        word_list.remove('')
    return word_list

# %%
# get data.txt from hadoop

data_from_hadoop_system = sc.textFile("/user/vagrant/data.txt")

# %%
# display what's inside data.txt

data_from_hadoop_system.collect()
# Out:
# ['Donald John Trump (born June 14, 1946) is the 45th and current president of the United States. Before entering politics, he was a businessman and television personality.',
#  "Trump was born and raised in Queens, a borough of New York City, and received a bachelor's degree in economics from the Wharton School. He took charge of his family's real-estate business in 1971, renamed it The Trump Organization, and expanded its operations from Queens and Brooklyn into Manhattan. The company built or renovated skyscrapers, hotels, casinos, and golf courses. Trump later started various side ventures, mostly by licensing his name. He owned the Miss Universe and Miss USA beauty pageants from 1996 to 2015 and produced and hosted The Apprentice, a reality television show, from 2003 to 2015. Forbes estimates his net worth to be $3.1 billion.[a]",
#  'Trump entered the 2016 presidential race as a Republican and defeated 16 other candidates in the primaries. His political positions have been described as populist, protectionist, and nationalist. Despite not being favored in most forecasts, he was elected over Democratic nominee Hillary Clinton, although he lost the popular vote. He became the oldest first-term U.S. president,[b] and the first without prior military or government service. His election and policies have sparked numerous protests. Trump has made many false or misleading statements during his campaign and presidency. The statements have been documented by fact-checkers, and the media have widely described the phenomenon as unprecedented in American politics. Many of his comments and actions have also been characterized as racially charged or racist.',
#  "During his presidency, Trump ordered a travel ban on citizens from several Muslim-majority countries, citing security concerns; after legal challenges, the Supreme Court upheld the policy's third revision. He enacted a tax-cut package for individuals and businesses, rescinding the individual health insurance mandate. He appointed Neil Gorsuch and Brett Kavanaugh to the Supreme Court. In foreign policy, Trump has pursued an America First agenda, withdrawing the U.S. from the Trans-Pacific Partnership trade negotiations, the Paris Agreement on climate change, and the Iran nuclear deal, eventually increasing tensions with the country. He recognized Jerusalem as the capital of Israel, imposed import tariffs triggering a trade war with China, and attempted negotiations with North Korea toward its denuclearization.",
#  'A special counsel investigation led by Robert Mueller found that Trump and his campaign welcomed and encouraged Russian foreign interference in the 2016 presidential election under the belief that it would be politically advantageous, but did not find sufficient evidence to press charges of criminal conspiracy or coordination with Russia. Mueller also investigated Trump for obstruction of justice, and his report neither indicted nor exonerated Trump on that count. A 2019 House impeachment inquiry found that Trump solicited foreign interference in the 2020 U.S. presidential election from Ukraine to help his re-election bid and then obstructed the inquiry itself. Trump was impeached by the House of Representatives on December 18, 2019, for abuse of power and obstruction of Congress. He is the third U.S. president to be impeached. The impeachment trial began on January 16, 2020, and on February 5 he was acquitted by the Senate of both charges.',
#  'Ngoai them chiec la vang roi, trong them chiec la dang roi mau vang. Dang roi la la mau vang, roi duoc mot luc la vang het roi.',
#  'Toi la hon soi buon, lan quanh cuoc doi bang nhung vong hiu quanh, chieu nay chot biet cho dung chan. Nguoi con gai toc dai che mat, em den tu dau va se ve dau ? Toi o lai voi lan dau gap go, xin chieu dung qua mau. Toi la ke ngu ngo bi tinh yeu danh luoi.']

# %%
# instead of using map transformation, I use flatMap (which return multiples value for an input)
# for example: input ["hello world", "duc loc"], lambda string: string.split(" ")

# if we use map transformation, the result will be something like: 
#                   [ ('hello', 'world'), ('duc', 'loc') ] --> only 2 results

# on the other hand, flatMap transformation will return something like: 
#                   ['hello', 'world', 'duc', 'loc'] --> we have 4 results

# finally, from a string of dataset, we have a list of word separatedly


words = data_from_hadoop_system.flatMap(lambda line: toWordList(line))

# %%
# Spark commands are using lazy evaluation. That means, they haven't really convert each line of
# dataset to a list of words yet. 
# this collect function will force Spark to take action on data by gather all result from clusters


words.collect()
# Out:
# ['donald',
#  'john',
#  'trump',
#  'born',
#  'june',
#  'is',
#  'the',
#  'th',
#  'and',
#  'current',
#  'president',
#  'of',
#  'the',
#  'united',
#  'states',
#  'before',
#  'entering',
#  'politics',
#  'he',
#  'was',
#  'a',
#  'businessman',
#  'and',
#  'television',
#  'personality',
#  'trump',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'in',
#  'queens',
#  'a',
#  'borough',
#  'of',
#  'new',
#  'york',
#  'city',
#  'and',
#  'received',
#  'a',
#  'bachelors',
#  'degree',
#  'in',
#  'economics',
#  'from',
#  'the',
#  'wharton',
#  'school',
#  'he',
#  'took',
#  'charge',
#  'of',
#  'his',
#  'familys',
#  'realestate',
#  'business',
#  'in',
#  'renamed',
#  'it',
#  'the',
#  'trump',
#  'organization',
#  'and',
#  'expanded',
#  'its',
#  'operations',
#  'from',
#  'queens',
#  'and',
#  'brooklyn',
#  'into',
#  'manhattan',
#  'the',
#  'company',
#  'built',
#  'or',
#  'renovated',
#  'skyscrapers',
#  'hotels',
#  'casinos',
#  'and',
#  'golf',
#  'courses',
#  'trump',
#  'later',
#  'started',
#  'various',
#  'side',
#  'ventures',
#  'mostly',
#  'by',
#  'licensing',
#  'his',
#  'name',
#  'he',
#  'owned',
#  'the',
#  'miss',
#  'universe',
#  'and',
#  'miss',
#  'usa',
#  'beauty',
#  'pageants',
#  'from',
#  'to',
#  'and',
#  'produced',
#  'and',
#  'hosted',
#  'the',
#  'apprentice',
#  'a',
#  'reality',
#  'television',
#  'show',
#  'from',
#  'to',
#  'forbes',
#  'estimates',
#  'his',
#  'net',
#  'worth',
#  'to',
#  'be',
#  'billiona',
#  'trump',
#  'entered',
#  'the',
#  'presidential',
#  'race',
#  'as',
#  'a',
#  'republican',
#  'and',
#  'defeated',
#  'other',
#  'candidates',
#  'in',
#  'the',
#  'primaries',
#  'his',
#  'political',
#  'positions',
#  'have',
#  'been',
#  'described',
#  'as',
#  'populist',
#  'protectionist',
#  'and',
#  'nationalist',
#  'despite',
#  'not',
#  'being',
#  'favored',
#  'in',
#  'most',
#  'forecasts',
#  'he',
#  'was',
#  'elected',
#  'over',
#  'democratic',
#  'nominee',
#  'hillary',
#  'clinton',
#  'although',
#  'he',
#  'lost',
#  'the',
#  'popular',
#  'vote',
#  'he',
#  'became',
#  'the',
#  'oldest',
#  'firstterm',
#  'us',
#  'presidentb',
#  'and',
#  'the',
#  'first',
#  'without',
#  'prior',
#  'military',
#  'or',
#  'government',
#  'service',
#  'his',
#  'election',
#  'and',
#  'policies',
#  'have',
#  'sparked',
#  'numerous',
#  'protests',
#  'trump',
#  'has',
#  'made',
#  'many',
#  'false',
#  'or',
#  'misleading',
#  'statements',
#  'during',
#  'his',
#  'campaign',
#  'and',
#  'presidency',
#  'the',
#  'statements',
#  'have',
#  'been',
#  'documented',
#  'by',
#  'factcheckers',
#  'and',
#  'the',
#  'media',
#  'have',
#  'widely',
#  'described',
#  'the',
#  'phenomenon',
#  'as',
#  'unprecedented',
#  'in',
#  'american',
#  'politics',
#  'many',
#  'of',
#  'his',
#  'comments',
#  'and',
#  'actions',
#  'have',
#  'also',
#  'been',
#  'characterized',
#  'as',
#  'racially',
#  'charged',
#  'or',
#  'racist',
#  'during',
#  'his',
#  'presidency',
#  'trump',
#  'ordered',
#  'a',
#  'travel',
#  'ban',
#  'on',
#  'citizens',
#  'from',
#  'several',
#  'muslimmajority',
#  'countries',
#  'citing',
#  'security',
#  'concerns',
#  'after',
#  'legal',
#  'challenges',
#  'the',
#  'supreme',
#  'court',
#  'upheld',
#  'the',
#  'policys',
#  'third',
#  'revision',
#  'he',
#  'enacted',
#  'a',
#  'taxcut',
#  'package',
#  'for',
#  'individuals',
#  'and',
#  'businesses',
#  'rescinding',
#  'the',
#  'individual',
#  'health',
#  'insurance',
#  'mandate',
#  'he',
#  'appointed',
#  'neil',
#  'gorsuch',
#  'and',
#  'brett',
#  'kavanaugh',
#  'to',
#  'the',
#  'supreme',
#  'court',
#  'in',
#  'foreign',
#  'policy',
#  'trump',
#  'has',
#  'pursued',
#  'an',
#  'america',
#  'first',
#  'agenda',
#  'withdrawing',
#  'the',
#  'us',
#  'from',
#  'the',
#  'transpacific',
#  'partnership',
#  'trade',
#  'negotiations',
#  'the',
#  'paris',
#  'agreement',
#  'on',
#  'climate',
#  'change',
#  'and',
#  'the',
#  'iran',
#  'nuclear',
#  'deal',
#  'eventually',
#  'increasing',
#  'tensions',
#  'with',
#  'the',
#  'country',
#  'he',
#  'recognized',
#  'jerusalem',
#  'as',
#  'the',
#  'capital',
#  'of',
#  'israel',
#  'imposed',
#  'import',
#  'tariffs',
#  'triggering',
#  'a',
#  'trade',
#  'war',
#  'with',
#  'china',
#  'and',
#  'attempted',
#  'negotiations',
#  'with',
#  'north',
#  'korea',
#  'toward',
#  'its',
#  'denuclearization',
#  'a',
#  'special',
#  'counsel',
#  'investigation',
#  'led',
#  'by',
#  'robert',
#  'mueller',
#  'found',
#  'that',
#  'trump',
#  'and',
#  'his',
#  'campaign',
#  'welcomed',
#  'and',
#  'encouraged',
#  'russian',
#  'foreign',
#  'interference',
#  'in',
#  'the',
#  'presidential',
#  'election',
#  'under',
#  'the',
#  'belief',
#  'that',
#  'it',
#  'would',
#  'be',
#  'politically',
#  'advantageous',
#  'but',
#  'did',
#  'not',
#  'find',
#  'sufficient',
#  'evidence',
#  'to',
#  'press',
#  'charges',
#  'of',
#  'criminal',
#  'conspiracy',
#  'or',
#  'coordination',
#  'with',
#  'russia',
#  'mueller',
#  'also',
#  'investigated',
#  'trump',
#  'for',
#  'obstruction',
#  'of',
#  'justice',
#  'and',
#  'his',
#  'report',
#  'neither',
#  'indicted',
#  'nor',
#  'exonerated',
#  'trump',
#  'on',
#  'that',
#  'count',
#  'a',
#  'house',
#  'impeachment',
#  'inquiry',
#  'found',
#  'that',
#  'trump',
#  'solicited',
#  'foreign',
#  'interference',
#  'in',
#  'the',
#  'us',
#  'presidential',
#  'election',
#  'from',
#  'ukraine',
#  'to',
#  'help',
#  'his',
#  'reelection',
#  'bid',
#  'and',
#  'then',
#  'obstructed',
#  'the',
#  'inquiry',
#  'itself',
#  'trump',
#  'was',
#  'impeached',
#  'by',
#  'the',
#  'house',
#  'of',
#  'representatives',
#  'on',
#  'december',
#  'for',
#  'abuse',
#  'of',
#  'power',
#  'and',
#  'obstruction',
#  'of',
#  'congress',
#  'he',
#  'is',
#  'the',
#  'third',
#  'us',
#  'president',
#  'to',
#  'be',
#  'impeached',
#  'the',
#  'impeachment',
#  'trial',
#  'began',
#  'on',
#  'january',
#  'and',
#  'on',
#  'february',
#  'he',
#  'was',
#  'acquitted',
#  'by',
#  'the',
#  'senate',
#  'of',
#  'both',
#  'charges',
#  'ngoai',
#  'them',
#  'chiec',
#  'la',
#  'vang',
#  'roi',
#  'trong',
#  'them',
#  'chiec',
#  'la',
#  'dang',
#  'roi',
#  'mau',
#  'vang',
#  'dang',
#  'roi',
#  'la',
#  'la',
#  'mau',
#  'vang',
#  'roi',
#  'duoc',
#  'mot',
#  'luc',
#  'la',
#  'vang',
#  'het',
#  'roi',
#  'toi',
#  'la',
#  'hon',
#  'soi',
#  'buon',
#  'lan',
#  'quanh',
#  'cuoc',
#  'doi',
#  'bang',
#  'nhung',
#  'vong',
#  'hiu',
#  'quanh',
#  'chieu',
#  'nay',
#  'chot',
#  'biet',
#  'cho',
#  'dung',
#  'chan',
#  'nguoi',
#  'con',
#  'gai',
#  'toc',
#  'dai',
#  'che',
#  'mat',
#  'em',
#  'den',
#  'tu',
#  'dau',
#  'va',
#  'se',
#  've',
#  'dau',
#  'toi',
#  'o',
#  'lai',
#  'voi',
#  'lan',
#  'dau',
#  'gap',
#  'go',
#  'xin',
#  'chieu',
#  'dung',
#  'qua',
#  'mau',
#  'toi',
#  'la',
#  'ke',
#  'ngu',
#  'ngo',
#  'bi',
#  'tinh',
#  'yeu',
#  'danh',
#  'luoi']

# %%
# first of all, we initialize each word in list with frequency 1 by using mapping operation
# ['hello', 'world'] --> [('hello', 1), ('world', 1)]


rdd = words.map(lambda word: (word, 1))
rdd.collect()
# Out:
# [('donald', 1),
#  ('john', 1),
#  ('trump', 1),
#  ('born', 1),
#  ('june', 1),
#  ('is', 1),
#  ('the', 1),
#  ('th', 1),
#  ('and', 1),
#  ('current', 1),
#  ('president', 1),
#  ('of', 1),
#  ('the', 1),
#  ('united', 1),
#  ('states', 1),
#  ('before', 1),
#  ('entering', 1),
#  ('politics', 1),
#  ('he', 1),
#  ('was', 1),
#  ('a', 1),
#  ('businessman', 1),
#  ('and', 1),
#  ('television', 1),
#  ('personality', 1),
#  ('trump', 1),
#  ('was', 1),
#  ('born', 1),
#  ('and', 1),
#  ('raised', 1),
#  ('in', 1),
#  ('queens', 1),
#  ('a', 1),
#  ('borough', 1),
#  ('of', 1),
#  ('new', 1),
#  ('york', 1),
#  ('city', 1),
#  ('and', 1),
#  ('received', 1),
#  ('a', 1),
#  ('bachelors', 1),
#  ('degree', 1),
#  ('in', 1),
#  ('economics', 1),
#  ('from', 1),
#  ('the', 1),
#  ('wharton', 1),
#  ('school', 1),
#  ('he', 1),
#  ('took', 1),
#  ('charge', 1),
#  ('of', 1),
#  ('his', 1),
#  ('familys', 1),
#  ('realestate', 1),
#  ('business', 1),
#  ('in', 1),
#  ('renamed', 1),
#  ('it', 1),
#  ('the', 1),
#  ('trump', 1),
#  ('organization', 1),
#  ('and', 1),
#  ('expanded', 1),
#  ('its', 1),
#  ('operations', 1),
#  ('from', 1),
#  ('queens', 1),
#  ('and', 1),
#  ('brooklyn', 1),
#  ('into', 1),
#  ('manhattan', 1),
#  ('the', 1),
#  ('company', 1),
#  ('built', 1),
#  ('or', 1),
#  ('renovated', 1),
#  ('skyscrapers', 1),
#  ('hotels', 1),
#  ('casinos', 1),
#  ('and', 1),
#  ('golf', 1),
#  ('courses', 1),
#  ('trump', 1),
#  ('later', 1),
#  ('started', 1),
#  ('various', 1),
#  ('side', 1),
#  ('ventures', 1),
#  ('mostly', 1),
#  ('by', 1),
#  ('licensing', 1),
#  ('his', 1),
#  ('name', 1),
#  ('he', 1),
#  ('owned', 1),
#  ('the', 1),
#  ('miss', 1),
#  ('universe', 1),
#  ('and', 1),
#  ('miss', 1),
#  ('usa', 1),
#  ('beauty', 1),
#  ('pageants', 1),
#  ('from', 1),
#  ('to', 1),
#  ('and', 1),
#  ('produced', 1),
#  ('and', 1),
#  ('hosted', 1),
#  ('the', 1),
#  ('apprentice', 1),
#  ('a', 1),
#  ('reality', 1),
#  ('television', 1),
#  ('show', 1),
#  ('from', 1),
#  ('to', 1),
#  ('forbes', 1),
#  ('estimates', 1),
#  ('his', 1),
#  ('net', 1),
#  ('worth', 1),
#  ('to', 1),
#  ('be', 1),
#  ('billiona', 1),
#  ('trump', 1),
#  ('entered', 1),
#  ('the', 1),
#  ('presidential', 1),
#  ('race', 1),
#  ('as', 1),
#  ('a', 1),
#  ('republican', 1),
#  ('and', 1),
#  ('defeated', 1),
#  ('other', 1),
#  ('candidates', 1),
#  ('in', 1),
#  ('the', 1),
#  ('primaries', 1),
#  ('his', 1),
#  ('political', 1),
#  ('positions', 1),
#  ('have', 1),
#  ('been', 1),
#  ('described', 1),
#  ('as', 1),
#  ('populist', 1),
#  ('protectionist', 1),
#  ('and', 1),
#  ('nationalist', 1),
#  ('despite', 1),
#  ('not', 1),
#  ('being', 1),
#  ('favored', 1),
#  ('in', 1),
#  ('most', 1),
#  ('forecasts', 1),
#  ('he', 1),
#  ('was', 1),
#  ('elected', 1),
#  ('over', 1),
#  ('democratic', 1),
#  ('nominee', 1),
#  ('hillary', 1),
#  ('clinton', 1),
#  ('although', 1),
#  ('he', 1),
#  ('lost', 1),
#  ('the', 1),
#  ('popular', 1),
#  ('vote', 1),
#  ('he', 1),
#  ('became', 1),
#  ('the', 1),
#  ('oldest', 1),
#  ('firstterm', 1),
#  ('us', 1),
#  ('presidentb', 1),
#  ('and', 1),
#  ('the', 1),
#  ('first', 1),
#  ('without', 1),
#  ('prior', 1),
#  ('military', 1),
#  ('or', 1),
#  ('government', 1),
#  ('service', 1),
#  ('his', 1),
#  ('election', 1),
#  ('and', 1),
#  ('policies', 1),
#  ('have', 1),
#  ('sparked', 1),
#  ('numerous', 1),
#  ('protests', 1),
#  ('trump', 1),
#  ('has', 1),
#  ('made', 1),
#  ('many', 1),
#  ('false', 1),
#  ('or', 1),
#  ('misleading', 1),
#  ('statements', 1),
#  ('during', 1),
#  ('his', 1),
#  ('campaign', 1),
#  ('and', 1),
#  ('presidency', 1),
#  ('the', 1),
#  ('statements', 1),
#  ('have', 1),
#  ('been', 1),
#  ('documented', 1),
#  ('by', 1),
#  ('factcheckers', 1),
#  ('and', 1),
#  ('the', 1),
#  ('media', 1),
#  ('have', 1),
#  ('widely', 1),
#  ('described', 1),
#  ('the', 1),
#  ('phenomenon', 1),
#  ('as', 1),
#  ('unprecedented', 1),
#  ('in', 1),
#  ('american', 1),
#  ('politics', 1),
#  ('many', 1),
#  ('of', 1),
#  ('his', 1),
#  ('comments', 1),
#  ('and', 1),
#  ('actions', 1),
#  ('have', 1),
#  ('also', 1),
#  ('been', 1),
#  ('characterized', 1),
#  ('as', 1),
#  ('racially', 1),
#  ('charged', 1),
#  ('or', 1),
#  ('racist', 1),
#  ('during', 1),
#  ('his', 1),
#  ('presidency', 1),
#  ('trump', 1),
#  ('ordered', 1),
#  ('a', 1),
#  ('travel', 1),
#  ('ban', 1),
#  ('on', 1),
#  ('citizens', 1),
#  ('from', 1),
#  ('several', 1),
#  ('muslimmajority', 1),
#  ('countries', 1),
#  ('citing', 1),
#  ('security', 1),
#  ('concerns', 1),
#  ('after', 1),
#  ('legal', 1),
#  ('challenges', 1),
#  ('the', 1),
#  ('supreme', 1),
#  ('court', 1),
#  ('upheld', 1),
#  ('the', 1),
#  ('policys', 1),
#  ('third', 1),
#  ('revision', 1),
#  ('he', 1),
#  ('enacted', 1),
#  ('a', 1),
#  ('taxcut', 1),
#  ('package', 1),
#  ('for', 1),
#  ('individuals', 1),
#  ('and', 1),
#  ('businesses', 1),
#  ('rescinding', 1),
#  ('the', 1),
#  ('individual', 1),
#  ('health', 1),
#  ('insurance', 1),
#  ('mandate', 1),
#  ('he', 1),
#  ('appointed', 1),
#  ('neil', 1),
#  ('gorsuch', 1),
#  ('and', 1),
#  ('brett', 1),
#  ('kavanaugh', 1),
#  ('to', 1),
#  ('the', 1),
#  ('supreme', 1),
#  ('court', 1),
#  ('in', 1),
#  ('foreign', 1),
#  ('policy', 1),
#  ('trump', 1),
#  ('has', 1),
#  ('pursued', 1),
#  ('an', 1),
#  ('america', 1),
#  ('first', 1),
#  ('agenda', 1),
#  ('withdrawing', 1),
#  ('the', 1),
#  ('us', 1),
#  ('from', 1),
#  ('the', 1),
#  ('transpacific', 1),
#  ('partnership', 1),
#  ('trade', 1),
#  ('negotiations', 1),
#  ('the', 1),
#  ('paris', 1),
#  ('agreement', 1),
#  ('on', 1),
#  ('climate', 1),
#  ('change', 1),
#  ('and', 1),
#  ('the', 1),
#  ('iran', 1),
#  ('nuclear', 1),
#  ('deal', 1),
#  ('eventually', 1),
#  ('increasing', 1),
#  ('tensions', 1),
#  ('with', 1),
#  ('the', 1),
#  ('country', 1),
#  ('he', 1),
#  ('recognized', 1),
#  ('jerusalem', 1),
#  ('as', 1),
#  ('the', 1),
#  ('capital', 1),
#  ('of', 1),
#  ('israel', 1),
#  ('imposed', 1),
#  ('import', 1),
#  ('tariffs', 1),
#  ('triggering', 1),
#  ('a', 1),
#  ('trade', 1),
#  ('war', 1),
#  ('with', 1),
#  ('china', 1),
#  ('and', 1),
#  ('attempted', 1),
#  ('negotiations', 1),
#  ('with', 1),
#  ('north', 1),
#  ('korea', 1),
#  ('toward', 1),
#  ('its', 1),
#  ('denuclearization', 1),
#  ('a', 1),
#  ('special', 1),
#  ('counsel', 1),
#  ('investigation', 1),
#  ('led', 1),
#  ('by', 1),
#  ('robert', 1),
#  ('mueller', 1),
#  ('found', 1),
#  ('that', 1),
#  ('trump', 1),
#  ('and', 1),
#  ('his', 1),
#  ('campaign', 1),
#  ('welcomed', 1),
#  ('and', 1),
#  ('encouraged', 1),
#  ('russian', 1),
#  ('foreign', 1),
#  ('interference', 1),
#  ('in', 1),
#  ('the', 1),
#  ('presidential', 1),
#  ('election', 1),
#  ('under', 1),
#  ('the', 1),
#  ('belief', 1),
#  ('that', 1),
#  ('it', 1),
#  ('would', 1),
#  ('be', 1),
#  ('politically', 1),
#  ('advantageous', 1),
#  ('but', 1),
#  ('did', 1),
#  ('not', 1),
#  ('find', 1),
#  ('sufficient', 1),
#  ('evidence', 1),
#  ('to', 1),
#  ('press', 1),
#  ('charges', 1),
#  ('of', 1),
#  ('criminal', 1),
#  ('conspiracy', 1),
#  ('or', 1),
#  ('coordination', 1),
#  ('with', 1),
#  ('russia', 1),
#  ('mueller', 1),
#  ('also', 1),
#  ('investigated', 1),
#  ('trump', 1),
#  ('for', 1),
#  ('obstruction', 1),
#  ('of', 1),
#  ('justice', 1),
#  ('and', 1),
#  ('his', 1),
#  ('report', 1),
#  ('neither', 1),
#  ('indicted', 1),
#  ('nor', 1),
#  ('exonerated', 1),
#  ('trump', 1),
#  ('on', 1),
#  ('that', 1),
#  ('count', 1),
#  ('a', 1),
#  ('house', 1),
#  ('impeachment', 1),
#  ('inquiry', 1),
#  ('found', 1),
#  ('that', 1),
#  ('trump', 1),
#  ('solicited', 1),
#  ('foreign', 1),
#  ('interference', 1),
#  ('in', 1),
#  ('the', 1),
#  ('us', 1),
#  ('presidential', 1),
#  ('election', 1),
#  ('from', 1),
#  ('ukraine', 1),
#  ('to', 1),
#  ('help', 1),
#  ('his', 1),
#  ('reelection', 1),
#  ('bid', 1),
#  ('and', 1),
#  ('then', 1),
#  ('obstructed', 1),
#  ('the', 1),
#  ('inquiry', 1),
#  ('itself', 1),
#  ('trump', 1),
#  ('was', 1),
#  ('impeached', 1),
#  ('by', 1),
#  ('the', 1),
#  ('house', 1),
#  ('of', 1),
#  ('representatives', 1),
#  ('on', 1),
#  ('december', 1),
#  ('for', 1),
#  ('abuse', 1),
#  ('of', 1),
#  ('power', 1),
#  ('and', 1),
#  ('obstruction', 1),
#  ('of', 1),
#  ('congress', 1),
#  ('he', 1),
#  ('is', 1),
#  ('the', 1),
#  ('third', 1),
#  ('us', 1),
#  ('president', 1),
#  ('to', 1),
#  ('be', 1),
#  ('impeached', 1),
#  ('the', 1),
#  ('impeachment', 1),
#  ('trial', 1),
#  ('began', 1),
#  ('on', 1),
#  ('january', 1),
#  ('and', 1),
#  ('on', 1),
#  ('february', 1),
#  ('he', 1),
#  ('was', 1),
#  ('acquitted', 1),
#  ('by', 1),
#  ('the', 1),
#  ('senate', 1),
#  ('of', 1),
#  ('both', 1),
#  ('charges', 1),
#  ('ngoai', 1),
#  ('them', 1),
#  ('chiec', 1),
#  ('la', 1),
#  ('vang', 1),
#  ('roi', 1),
#  ('trong', 1),
#  ('them', 1),
#  ('chiec', 1),
#  ('la', 1),
#  ('dang', 1),
#  ('roi', 1),
#  ('mau', 1),
#  ('vang', 1),
#  ('dang', 1),
#  ('roi', 1),
#  ('la', 1),
#  ('la', 1),
#  ('mau', 1),
#  ('vang', 1),
#  ('roi', 1),
#  ('duoc', 1),
#  ('mot', 1),
#  ('luc', 1),
#  ('la', 1),
#  ('vang', 1),
#  ('het', 1),
#  ('roi', 1),
#  ('toi', 1),
#  ('la', 1),
#  ('hon', 1),
#  ('soi', 1),
#  ('buon', 1),
#  ('lan', 1),
#  ('quanh', 1),
#  ('cuoc', 1),
#  ('doi', 1),
#  ('bang', 1),
#  ('nhung', 1),
#  ('vong', 1),
#  ('hiu', 1),
#  ('quanh', 1),
#  ('chieu', 1),
#  ('nay', 1),
#  ('chot', 1),
#  ('biet', 1),
#  ('cho', 1),
#  ('dung', 1),
#  ('chan', 1),
#  ('nguoi', 1),
#  ('con', 1),
#  ('gai', 1),
#  ('toc', 1),
#  ('dai', 1),
#  ('che', 1),
#  ('mat', 1),
#  ('em', 1),
#  ('den', 1),
#  ('tu', 1),
#  ('dau', 1),
#  ('va', 1),
#  ('se', 1),
#  ('ve', 1),
#  ('dau', 1),
#  ('toi', 1),
#  ('o', 1),
#  ('lai', 1),
#  ('voi', 1),
#  ('lan', 1),
#  ('dau', 1),
#  ('gap', 1),
#  ('go', 1),
#  ('xin', 1),
#  ('chieu', 1),
#  ('dung', 1),
#  ('qua', 1),
#  ('mau', 1),
#  ('toi', 1),
#  ('la', 1),
#  ('ke', 1),
#  ('ngu', 1),
#  ('ngo', 1),
#  ('bi', 1),
#  ('tinh', 1),
#  ('yeu', 1),
#  ('danh', 1),
#  ('luoi', 1)]

# %%
# this lazy transformation is implemented to aggregate each input by key
# at the moment, input is in form [('hello', 1), ('world', 1), ('hello', 2)]
# 'hello' and 'world', the entry of each tuple, is consider to be the key
# after aggregate operation (sum in our exercise), the result should be: [('hello', 1+2), ('world', 1)]

rdd = rdd.reduceByKey(lambda x, y: x+y)
rdd.collect()
# Out:
# [('john', 1),
#  ('june', 1),
#  ('is', 2),
#  ('current', 1),
#  ('of', 11),
#  ('united', 1),
#  ('before', 1),
#  ('entering', 1),
#  ('politics', 2),
#  ('he', 11),
#  ('was', 5),
#  ('television', 2),
#  ('personality', 1),
#  ('raised', 1),
#  ('in', 9),
#  ('queens', 2),
#  ('new', 1),
#  ('york', 1),
#  ('bachelors', 1),
#  ('economics', 1),
#  ('wharton', 1),
#  ('school', 1),
#  ('took', 1),
#  ('charge', 1),
#  ('his', 11),
#  ('realestate', 1),
#  ('business', 1),
#  ('renamed', 1),
#  ('operations', 1),
#  ('brooklyn', 1),
#  ('into', 1),
#  ('renovated', 1),
#  ('started', 1),
#  ('ventures', 1),
#  ('name', 1),
#  ('universe', 1),
#  ('usa', 1),
#  ('beauty', 1),
#  ('produced', 1),
#  ('apprentice', 1),
#  ('forbes', 1),
#  ('estimates', 1),
#  ('worth', 1),
#  ('billiona', 1),
#  ('entered', 1),
#  ('presidential', 3),
#  ('race', 1),
#  ('as', 5),
#  ('defeated', 1),
#  ('other', 1),
#  ('candidates', 1),
#  ('political', 1),
#  ('positions', 1),
#  ('have', 5),
#  ('populist', 1),
#  ('protectionist', 1),
#  ('despite', 1),
#  ('democratic', 1),
#  ('hillary', 1),
#  ('clinton', 1),
#  ('although', 1),
#  ('lost', 1),
#  ('vote', 1),
#  ('oldest', 1),
#  ('us', 4),
#  ('service', 1),
#  ('policies', 1),
#  ('during', 2),
#  ('widely', 1),
#  ('unprecedented', 1),
#  ('comments', 1),
#  ('ban', 1),
#  ('citizens', 1),
#  ('several', 1),
#  ('muslimmajority', 1),
#  ('countries', 1),
#  ('citing', 1),
#  ('security', 1),
#  ('concerns', 1),
#  ('after', 1),
#  ('legal', 1),
#  ('challenges', 1),
#  ('policys', 1),
#  ('third', 2),
#  ('revision', 1),
#  ('enacted', 1),
#  ('individuals', 1),
#  ('businesses', 1),
#  ('individual', 1),
#  ('insurance', 1),
#  ('mandate', 1),
#  ('kavanaugh', 1),
#  ('foreign', 3),
#  ('policy', 1),
#  ('an', 1),
#  ('america', 1),
#  ('withdrawing', 1),
#  ('trade', 2),
#  ('negotiations', 2),
#  ('paris', 1),
#  ('agreement', 1),
#  ('climate', 1),
#  ('change', 1),
#  ('iran', 1),
#  ('nuclear', 1),
#  ('deal', 1),
#  ('eventually', 1),
#  ('country', 1),
#  ('import', 1),
#  ('tariffs', 1),
#  ('triggering', 1),
#  ('attempted', 1),
#  ('toward', 1),
#  ('denuclearization', 1),
#  ('investigation', 1),
#  ('led', 1),
#  ('robert', 1),
#  ('welcomed', 1),
#  ('encouraged', 1),
#  ('belief', 1),
#  ('would', 1),
#  ('advantageous', 1),
#  ('but', 1),
#  ('evidence', 1),
#  ('charges', 2),
#  ('coordination', 1),
#  ('neither', 1),
#  ('nor', 1),
#  ('count', 1),
#  ('house', 2),
#  ('inquiry', 2),
#  ('help', 1),
#  ('bid', 1),
#  ('obstructed', 1),
#  ('power', 1),
#  ('congress', 1),
#  ('trial', 1),
#  ('january', 1),
#  ('february', 1),
#  ('both', 1),
#  ('them', 2),
#  ('chiec', 2),
#  ('vang', 4),
#  ('trong', 1),
#  ('dang', 2),
#  ('duoc', 1),
#  ('toi', 3),
#  ('hon', 1),
#  ('soi', 1),
#  ('cuoc', 1),
#  ('chieu', 2),
#  ('chot', 1),
#  ('con', 1),
#  ('toc', 1),
#  ('dai', 1),
#  ('em', 1),
#  ('dau', 3),
#  ('va', 1),
#  ('ve', 1),
#  ('gap', 1),
#  ('go', 1),
#  ('ngu', 1),
#  ('tinh', 1),
#  ('yeu', 1),
#  ('a', 10),
#  ('special', 1),
#  ('counsel', 1),
#  ('by', 5),
#  ('mueller', 2),
#  ('found', 2),
#  ('that', 4),
#  ('trump', 13),
#  ('and', 27),
#  ('campaign', 2),
#  ('russian', 1),
#  ('interference', 2),
#  ('the', 33),
#  ('election', 3),
#  ('under', 1),
#  ('it', 2),
#  ('be', 3),
#  ('politically', 1),
#  ('did', 1),
#  ('not', 2),
#  ('find', 1),
#  ('sufficient', 1),
#  ('to', 7),
#  ('press', 1),
#  ('criminal', 1),
#  ('conspiracy', 1),
#  ('or', 5),
#  ('with', 4),
#  ('russia', 1),
#  ('also', 2),
#  ('investigated', 1),
#  ('for', 3),
#  ('obstruction', 2),
#  ('justice', 1),
#  ('report', 1),
#  ('indicted', 1),
#  ('exonerated', 1),
#  ('on', 6),
#  ('impeachment', 2),
#  ('solicited', 1),
#  ('from', 7),
#  ('ukraine', 1),
#  ('reelection', 1),
#  ('then', 1),
#  ('itself', 1),
#  ('impeached', 2),
#  ('representatives', 1),
#  ('december', 1),
#  ('abuse', 1),
#  ('president', 2),
#  ('began', 1),
#  ('acquitted', 1),
#  ('senate', 1),
#  ('ngoai', 1),
#  ('la', 7),
#  ('roi', 5),
#  ('mau', 3),
#  ('mot', 1),
#  ('luc', 1),
#  ('het', 1),
#  ('buon', 1),
#  ('lan', 2),
#  ('quanh', 2),
#  ('doi', 1),
#  ('bang', 1),
#  ('nhung', 1),
#  ('vong', 1),
#  ('hiu', 1),
#  ('nay', 1),
#  ('biet', 1),
#  ('cho', 1),
#  ('dung', 2),
#  ('chan', 1),
#  ('nguoi', 1),
#  ('gai', 1),
#  ('che', 1),
#  ('mat', 1),
#  ('den', 1),
#  ('tu', 1),
#  ('se', 1),
#  ('o', 1),
#  ('lai', 1),
#  ('voi', 1),
#  ('xin', 1),
#  ('qua', 1),
#  ('ke', 1),
#  ('ngo', 1),
#  ('bi', 1),
#  ('danh', 1),
#  ('luoi', 1),
#  ('donald', 1),
#  ('born', 2),
#  ('th', 1),
#  ('states', 1),
#  ('businessman', 1),
#  ('borough', 1),
#  ('city', 1),
#  ('received', 1),
#  ('degree', 1),
#  ('familys', 1),
#  ('organization', 1),
#  ('expanded', 1),
#  ('its', 2),
#  ('manhattan', 1),
#  ('company', 1),
#  ('built', 1),
#  ('skyscrapers', 1),
#  ('hotels', 1),
#  ('casinos', 1),
#  ('golf', 1),
#  ('courses', 1),
#  ('later', 1),
#  ('various', 1),
#  ('side', 1),
#  ('mostly', 1),
#  ('licensing', 1),
#  ('owned', 1),
#  ('miss', 2),
#  ('pageants', 1),
#  ('hosted', 1),
#  ('reality', 1),
#  ('show', 1),
#  ('net', 1),
#  ('republican', 1),
#  ('primaries', 1),
#  ('been', 3),
#  ('described', 2),
#  ('nationalist', 1),
#  ('being', 1),
#  ('favored', 1),
#  ('most', 1),
#  ('forecasts', 1),
#  ('elected', 1),
#  ('over', 1),
#  ('nominee', 1),
#  ('popular', 1),
#  ('became', 1),
#  ('firstterm', 1),
#  ('presidentb', 1),
#  ('first', 2),
#  ('without', 1),
#  ('prior', 1),
#  ('military', 1),
#  ('government', 1),
#  ('sparked', 1),
#  ('numerous', 1),
#  ('protests', 1),
#  ('has', 2),
#  ('made', 1),
#  ('many', 2),
#  ('false', 1),
#  ('misleading', 1),
#  ('statements', 2),
#  ('presidency', 2),
#  ('documented', 1),
#  ('factcheckers', 1),
#  ('media', 1),
#  ('phenomenon', 1),
#  ('american', 1),
#  ('actions', 1),
#  ('characterized', 1),
#  ('racially', 1),
#  ('charged', 1),
#  ('racist', 1),
#  ('ordered', 1),
#  ('travel', 1),
#  ('supreme', 2),
#  ('court', 2),
#  ('upheld', 1),
#  ('taxcut', 1),
#  ('package', 1),
#  ('rescinding', 1),
#  ('health', 1),
#  ('appointed', 1),
#  ('neil', 1),
#  ('gorsuch', 1),
#  ('brett', 1),
#  ('pursued', 1),
#  ('agenda', 1),
#  ('transpacific', 1),
#  ('partnership', 1),
#  ('increasing', 1),
#  ('tensions', 1),
#  ('recognized', 1),
#  ('jerusalem', 1),
#  ('capital', 1),
#  ('israel', 1),
#  ('imposed', 1),
#  ('war', 1),
#  ('china', 1),
#  ('north', 1),
#  ('korea', 1)]

# %%
# spark supply an sortByKey function
# our previous result form is (word, frequency)
# to sort this list base on frequency, we transfer the previous one to this form: (frequency, word)
# now, this is our final result - a list of word count

result = rdd.map(lambda x: (x[1], x[0])).sortByKey(ascending=False)

# %%
result.collect()
# Out:
# [(33, 'the'),
#  (27, 'and'),
#  (13, 'trump'),
#  (11, 'of'),
#  (11, 'he'),
#  (11, 'his'),
#  (10, 'a'),
#  (9, 'in'),
#  (7, 'to'),
#  (7, 'from'),
#  (7, 'la'),
#  (6, 'on'),
#  (5, 'by'),
#  (5, 'or'),
#  (5, 'roi'),
#  (5, 'was'),
#  (5, 'as'),
#  (5, 'have'),
#  (4, 'that'),
#  (4, 'with'),
#  (4, 'us'),
#  (4, 'vang'),
#  (3, 'election'),
#  (3, 'be'),
#  (3, 'for'),
#  (3, 'mau'),
#  (3, 'been'),
#  (3, 'presidential'),
#  (3, 'foreign'),
#  (3, 'toi'),
#  (3, 'dau'),
#  (2, 'mueller'),
#  (2, 'found'),
#  (2, 'campaign'),
#  (2, 'interference'),
#  (2, 'it'),
#  (2, 'not'),
#  (2, 'also'),
#  (2, 'obstruction'),
#  (2, 'impeachment'),
#  (2, 'impeached'),
#  (2, 'president'),
#  (2, 'lan'),
#  (2, 'quanh'),
#  (2, 'dung'),
#  (2, 'born'),
#  (2, 'its'),
#  (2, 'miss'),
#  (2, 'described'),
#  (2, 'first'),
#  (2, 'has'),
#  (2, 'many'),
#  (2, 'statements'),
#  (2, 'presidency'),
#  (2, 'supreme'),
#  (2, 'court'),
#  (2, 'is'),
#  (2, 'politics'),
#  (2, 'television'),
#  (2, 'queens'),
#  (2, 'during'),
#  (2, 'third'),
#  (2, 'trade'),
#  (2, 'negotiations'),
#  (2, 'charges'),
#  (2, 'house'),
#  (2, 'inquiry'),
#  (2, 'them'),
#  (2, 'chiec'),
#  (2, 'dang'),
#  (2, 'chieu'),
#  (1, 'john'),
#  (1, 'june'),
#  (1, 'current'),
#  (1, 'united'),
#  (1, 'before'),
#  (1, 'entering'),
#  (1, 'personality'),
#  (1, 'raised'),
#  (1, 'new'),
#  (1, 'york'),
#  (1, 'bachelors'),
#  (1, 'economics'),
#  (1, 'wharton'),
#  (1, 'school'),
#  (1, 'took'),
#  (1, 'charge'),
#  (1, 'realestate'),
#  (1, 'business'),
#  (1, 'renamed'),
#  (1, 'operations'),
#  (1, 'brooklyn'),
#  (1, 'into'),
#  (1, 'renovated'),
#  (1, 'started'),
#  (1, 'ventures'),
#  (1, 'name'),
#  (1, 'universe'),
#  (1, 'usa'),
#  (1, 'beauty'),
#  (1, 'produced'),
#  (1, 'apprentice'),
#  (1, 'forbes'),
#  (1, 'estimates'),
#  (1, 'worth'),
#  (1, 'billiona'),
#  (1, 'entered'),
#  (1, 'race'),
#  (1, 'defeated'),
#  (1, 'other'),
#  (1, 'candidates'),
#  (1, 'political'),
#  (1, 'positions'),
#  (1, 'populist'),
#  (1, 'protectionist'),
#  (1, 'despite'),
#  (1, 'democratic'),
#  (1, 'hillary'),
#  (1, 'clinton'),
#  (1, 'although'),
#  (1, 'lost'),
#  (1, 'vote'),
#  (1, 'oldest'),
#  (1, 'service'),
#  (1, 'policies'),
#  (1, 'widely'),
#  (1, 'unprecedented'),
#  (1, 'comments'),
#  (1, 'ban'),
#  (1, 'citizens'),
#  (1, 'several'),
#  (1, 'muslimmajority'),
#  (1, 'countries'),
#  (1, 'citing'),
#  (1, 'security'),
#  (1, 'concerns'),
#  (1, 'after'),
#  (1, 'legal'),
#  (1, 'challenges'),
#  (1, 'policys'),
#  (1, 'revision'),
#  (1, 'enacted'),
#  (1, 'individuals'),
#  (1, 'businesses'),
#  (1, 'individual'),
#  (1, 'insurance'),
#  (1, 'mandate'),
#  (1, 'kavanaugh'),
#  (1, 'policy'),
#  (1, 'an'),
#  (1, 'america'),
#  (1, 'withdrawing'),
#  (1, 'paris'),
#  (1, 'agreement'),
#  (1, 'climate'),
#  (1, 'change'),
#  (1, 'iran'),
#  (1, 'nuclear'),
#  (1, 'deal'),
#  (1, 'eventually'),
#  (1, 'country'),
#  (1, 'import'),
#  (1, 'tariffs'),
#  (1, 'triggering'),
#  (1, 'attempted'),
#  (1, 'toward'),
#  (1, 'denuclearization'),
#  (1, 'investigation'),
#  (1, 'led'),
#  (1, 'robert'),
#  (1, 'welcomed'),
#  (1, 'encouraged'),
#  (1, 'belief'),
#  (1, 'would'),
#  (1, 'advantageous'),
#  (1, 'but'),
#  (1, 'evidence'),
#  (1, 'coordination'),
#  (1, 'neither'),
#  (1, 'nor'),
#  (1, 'count'),
#  (1, 'help'),
#  (1, 'bid'),
#  (1, 'obstructed'),
#  (1, 'power'),
#  (1, 'congress'),
#  (1, 'trial'),
#  (1, 'january'),
#  (1, 'february'),
#  (1, 'both'),
#  (1, 'trong'),
#  (1, 'duoc'),
#  (1, 'hon'),
#  (1, 'soi'),
#  (1, 'cuoc'),
#  (1, 'chot'),
#  (1, 'con'),
#  (1, 'toc'),
#  (1, 'dai'),
#  (1, 'em'),
#  (1, 'va'),
#  (1, 've'),
#  (1, 'gap'),
#  (1, 'go'),
#  (1, 'ngu'),
#  (1, 'tinh'),
#  (1, 'yeu'),
#  (1, 'special'),
#  (1, 'counsel'),
#  (1, 'russian'),
#  (1, 'under'),
#  (1, 'politically'),
#  (1, 'did'),
#  (1, 'find'),
#  (1, 'sufficient'),
#  (1, 'press'),
#  (1, 'criminal'),
#  (1, 'conspiracy'),
#  (1, 'russia'),
#  (1, 'investigated'),
#  (1, 'justice'),
#  (1, 'report'),
#  (1, 'indicted'),
#  (1, 'exonerated'),
#  (1, 'solicited'),
#  (1, 'ukraine'),
#  (1, 'reelection'),
#  (1, 'then'),
#  (1, 'itself'),
#  (1, 'representatives'),
#  (1, 'december'),
#  (1, 'abuse'),
#  (1, 'began'),
#  (1, 'acquitted'),
#  (1, 'senate'),
#  (1, 'ngoai'),
#  (1, 'mot'),
#  (1, 'luc'),
#  (1, 'het'),
#  (1, 'buon'),
#  (1, 'doi'),
#  (1, 'bang'),
#  (1, 'nhung'),
#  (1, 'vong'),
#  (1, 'hiu'),
#  (1, 'nay'),
#  (1, 'biet'),
#  (1, 'cho'),
#  (1, 'chan'),
#  (1, 'nguoi'),
#  (1, 'gai'),
#  (1, 'che'),
#  (1, 'mat'),
#  (1, 'den'),
#  (1, 'tu'),
#  (1, 'se'),
#  (1, 'o'),
#  (1, 'lai'),
#  (1, 'voi'),
#  (1, 'xin'),
#  (1, 'qua'),
#  (1, 'ke'),
#  (1, 'ngo'),
#  (1, 'bi'),
#  (1, 'danh'),
#  (1, 'luoi'),
#  (1, 'donald'),
#  (1, 'th'),
#  (1, 'states'),
#  (1, 'businessman'),
#  (1, 'borough'),
#  (1, 'city'),
#  (1, 'received'),
#  (1, 'degree'),
#  (1, 'familys'),
#  (1, 'organization'),
#  (1, 'expanded'),
#  (1, 'manhattan'),
#  (1, 'company'),
#  (1, 'built'),
#  (1, 'skyscrapers'),
#  (1, 'hotels'),
#  (1, 'casinos'),
#  (1, 'golf'),
#  (1, 'courses'),
#  (1, 'later'),
#  (1, 'various'),
#  (1, 'side'),
#  (1, 'mostly'),
#  (1, 'licensing'),
#  (1, 'owned'),
#  (1, 'pageants'),
#  (1, 'hosted'),
#  (1, 'reality'),
#  (1, 'show'),
#  (1, 'net'),
#  (1, 'republican'),
#  (1, 'primaries'),
#  (1, 'nationalist'),
#  (1, 'being'),
#  (1, 'favored'),
#  (1, 'most'),
#  (1, 'forecasts'),
#  (1, 'elected'),
#  (1, 'over'),
#  (1, 'nominee'),
#  (1, 'popular'),
#  (1, 'became'),
#  (1, 'firstterm'),
#  (1, 'presidentb'),
#  (1, 'without'),
#  (1, 'prior'),
#  (1, 'military'),
#  (1, 'government'),
#  (1, 'sparked'),
#  (1, 'numerous'),
#  (1, 'protests'),
#  (1, 'made'),
#  (1, 'false'),
#  (1, 'misleading'),
#  (1, 'documented'),
#  (1, 'factcheckers'),
#  (1, 'media'),
#  (1, 'phenomenon'),
#  (1, 'american'),
#  (1, 'actions'),
#  (1, 'characterized'),
#  (1, 'racially'),
#  (1, 'charged'),
#  (1, 'racist'),
#  (1, 'ordered'),
#  (1, 'travel'),
#  (1, 'upheld'),
#  (1, 'taxcut'),
#  (1, 'package'),
#  (1, 'rescinding'),
#  (1, 'health'),
#  (1, 'appointed'),
#  (1, 'neil'),
#  (1, 'gorsuch'),
#  (1, 'brett'),
#  (1, 'pursued'),
#  (1, 'agenda'),
#  (1, 'transpacific'),
#  (1, 'partnership'),
#  (1, 'increasing'),
#  (1, 'tensions'),
#  (1, 'recognized'),
#  (1, 'jerusalem'),
#  (1, 'capital'),
#  (1, 'israel'),
#  (1, 'imposed'),
#  (1, 'war'),
#  (1, 'china'),
#  (1, 'north'),
#  (1, 'korea')]
